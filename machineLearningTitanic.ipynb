# %% [markdown]
# # Predict Survival of the Titanic Passengers

# %% [markdown]
# You will use logistic regression method to predict if a passenger survived the Ill-fated voyage of the Titanic (1912). The passenger data includes name, age, ticket class, and sex.  If you watched the Titanic movie, you might recall that the first class passengers and women with children received preference to lifeboats.  Hence, gender, age, and ticket class could be the key predictors of survival.

# %% [markdown]
# ## Table of Contents
# - [Titanic Data](#Titanic_Data)
# - [Load Libraries](#load_libraries)
# - [Access data](#access_data)
# - [Explore Data](#Explore)
# - [Parse Data](#Parse)
# - [Split Data into Training and Test set](#training_test)
# - [Build Logistic Regression Model](#build_model)
# - [Predict for Test data](#test_data)
# - [Evaluate the Model](#evaluate_model)
# - [ROC curve plot](#ROC_plot)

# %% [markdown]
# <a id="Titanic_Data"></a>
# ## Titanic Data
# You will analyze the random sample of the Titanic passengers data. The Dataset Source: [https://ww2.amstat.org/publications/jse/v3n3/datasets.dawson.html](https://ww2.amstat.org/publications/jse/v3n3/datasets.dawson.html)

# %% [markdown]
#  <table style="font-size: 16px; text-align: left;" width=100%>
#   <tr>
#   <td width=5% style="text-align: center; font-size: 16px">
#    </td>
#    <td width=11% style="text-align: left; font-size: 16px">
#    <b>Variable</b>
#    </td>
#    <td width=53% style="text-align: left; font-size: 16px">
#    <b> Description</b>
#    </td>
#     <td width=31% rowspan=7>
#
#    <img src='https://www.khaskhabar.com/images/picture_image/3690-titanic-ship.jpg?raw=true'></img>
#
#   </td>
#   </tr>
#   <tr>
#    <td width=5% style="text-align: center; font-size: 16px">
#      0
#    </td>
#    <td width=11% style="text-align: left; font-size: 16px">
#      Name
#    </td>
#    <td width=53% style="text-align: left; font-size: 16px">
#      Passenger's first and last name.
#    </td>
#
#  </tr>
#  <tr>
#    <td style="text-align: center; font-size: 16px">
#     1
#   </td>
#   <td style="text-align: left; font-size: 16px">
#    PClass
#   </td>
#   <td style="text-align: left; font-size: 16px">
#    Ticket class (1st, 2nd, or 3rd) based on socio-economic status
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 16px">
#    2
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   Age
#   </td>
#   <td  style="text-align: left; font-size: 16px">
#   Passenger's estimated age in years
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 16px">
#   3
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   Sex
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   male or female
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 16px">
#   4
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   Survived
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   Indicates if the passenger survived the sinking of the Titanic (1=survived; 0=died)
#   </td>
#  </tr>
#  <tr>
#   <td style="text-align: center; font-size: 16px">
#    5
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   PersonID
#   </td>
#   <td style="text-align: left; font-size: 16px">
#   Passenger's unique identifier
#   </td>
#  </tr>
# </table>

# %% [markdown]
# <a id="load_libraries"></a>
# ## Load Libraries
#
# The Spark and Python libraries that you need are preinstalled in the notebook environment and only need to be loaded.
#
# Run the following cell to load the libraries you will work with in this notebook:

# %%
# PySpark Machine Learning Library
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.sql import Row, SQLContext

import os
import sys
from pyspark import SparkConf
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.types import *

from pyspark.mllib.classification import LogisticRegressionWithSGD
from pyspark.mllib.regression import LabeledPoint
from numpy import array

from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Library for confusion matrix, precision, test error
from pyspark.mllib.evaluation import MulticlassMetrics
# Library For Area under ROC curve and Area under precision-recall curve
from pyspark.mllib.evaluation import BinaryClassificationMetrics

# Assign resources to the application
sqlContext = SQLContext(sc)

# packages for data analysis
import numpy as np
import pandas as pd
# Out:
# /opt/ibm/spark/python/lib/pyspark.zip/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.

# %%
# The data will be loaded into an array.
# This is the summary of the data structure, including the column position and name.
# The first filed starts from position 0. 

# 0 Name    -  Passenger first and last name.
# 1 PClass  -  Ticket class (1st, 2nd, or 3rd) based on Socio-Economic status
# 2 Age
# 3 Sex
# 4 Survived -  1 if the passenger survived;  0 if the passenger died
# 5 PersonID

# Label is a target variable. PersonInfo is a list of independent variables besides unique identifier

LabeledDocument = Row("PersonID", "PersonInfo", "label")

# Define a function that parses each raw in CSV file and returns an object of type LabeledDocument

def parseDocument(line):
    values = [str(x) for x in line.split(',')] 
    if (values[4]>'0'):
      Survived = 1.0
    else:
      Survived = 0.0
        
    textValue = str(values[1]) + " " + str(values[2])+" " + str(values[3])
    return LabeledDocument(values[5], textValue, Survived)

# %% [markdown]
# <a id="access_data"></a>
# ## Access Data
# To read a file from Object Storage, you must setup the Spark configuration with your Object Storage credentials.
#
# To do this, click on the cell below and select the **Insert to code > Insert Spark Session DataFrame** function from the Files tab below the data file you want to work with.

# %% [markdown]
# <div class="alert alert-block alert-info">The following code contains the credentials for a file in your IBM Cloud Object Storage. </div>

# %%
import ibmos2spark

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

metadata = {
    'endpoint': 'https://s3.direct.us-south.cloud-object-storage.appdomain.cloud',
    'service_id': 'iam-ServiceId-0b6d4da6-6f6a-4853-8aca-d1d3452a0eaf',
    'iam_service_endpoint': 'https://iam.cloud.ibm.com/identity/token',
    'api_key': 'xo6AVFB5lcyHhrLgoOQ5l0fTO4W9kDAwlZilUiTng1QI'
}

configuration_name = 'os_39af822dd9d540dc999554a39edaf099_configs'
cos = ibmos2spark.CloudObjectStorage(sc, metadata, configuration_name, 'bluemix_cos')
url = cos.url('Titanic.csv', 'apachesparktutorial-donotdelete-pr-2mqcsudxch8wzx')

df_data_1 = spark.read \
    .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat') \
    .option('header', 'true') \
    .option('inferSchema', 'true') \
    .load(url)
df_data_1.show(10)
# Out:
# +--------------------+------+----+------+--------+--------+
# |                Name|PClass| Age|   Sex|Survived|PersonID|
# +--------------------+------+----+------+--------+--------+
# |Allen Miss Elisab...|   1st|29.0|female|       1|       1|
# |Allison Miss Hele...|   1st| 2.0|female|       0|       2|
# |Allison Mr Hudson...|   1st|30.0|  male|       0|       3|
# |Allison Mrs Hudso...|   1st|25.0|female|       0|       4|
# |Allison Master Hu...|   1st|0.92|  male|       1|       5|
# |   Anderson Mr Harry|   1st|47.0|  male|       1|       6|
# |Andrews Miss Korn...|   1st|63.0|female|       1|       7|
# |Andrews Mr Thomas jr|   1st|39.0|  male|       0|       8|
# |Appleton Mrs Edwa...|   1st|58.0|female|       1|       9|
# |Artagaveytia Mr R...|   1st|71.0|  male|       0|      10|
# +--------------------+------+----+------+--------+--------+
# only showing top 10 rows

# %% [markdown]
# <a id="Explore"></a>
# ## Explore Data

# %%
print('Number of Passengers', df_data_1.count())
# Out:
# Number of Passengers 756

# %%
#Number of passengers who survived and number passengers who died
df_data_1.groupby('Survived').count().show()
# Out:
# +--------+-----+
# |Survived|count|
# +--------+-----+
# |       1|  313|
# |       0|  443|
# +--------+-----+

# %%
#Number of passengers who survived and number passengers who died by Socio-Economic class
import matplotlib.pyplot as plt
# %matplotlib inline
df_data_1.crosstab('PClass', 'Survived').show()
df=df_data_1.crosstab('PClass', 'Survived').toPandas()
df.plot.bar(x="PClass_Survived", legend=True , title="Survival by Socio-Economic Class")
# Out:
# +---------------+---+---+
# |PClass_Survived|  0|  1|
# +---------------+---+---+
# |            2nd|116| 96|
# |            1st| 87|139|
# |            3rd|240| 78|
# +---------------+---+---+
# <Axes: title={'center': 'Survival by Socio-Economic Class'}, xlabel='PClass_Survived'>

# %%
# Average age by survival outcome
# Convert Age data type from string to numeric.
pdf=df_data_1.toPandas()
pdf["Age"]=pd.to_numeric(pdf.Age)

df=sqlContext.createDataFrame(pdf)

PAge=df.groupby(['Survived'])\
.agg({"Age": "AVG"}).toPandas()
PAge
# Out:
#    Survived   avg(Age)
# 0         0  31.131670
# 1         1  29.359585

# %%
#Age distribution for all passengers
df.toPandas()["Age"].hist(bins=20, figsize=(8, 6))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# <a id="Parse"></a>
# ## Parse Data
# Now let's load the data into a `Spark RDD` and output the number of rows and first 5 rows.
# Each project you create has a bucket in your object storage. You may get the bucket name from the project Settings page. Replace the string `BUCKET` to the bucket name

# %%
data = sc.textFile(cos.url('Titanic.csv', 'apachesparktutorial-donotdelete-pr-2mqcsudxch8wzx'))
print ("Total records in the data set:", data.count())
print ("The first 5 rows")
data.take(5)
# Out:
# Total records in the data set: 757
# The first 5 rows
# ['Name,PClass,Age,Sex,Survived,PersonID',
#  'Allen Miss Elisabeth Walton,1st,29,female,1,1',
#  'Allison Miss Helen Loraine,1st,2,female,0,2',
#  'Allison Mr Hudson Joshua Creighton,1st,30,male,0,3',
#  'Allison Mrs Hudson JC (Bessie Waldo Daniels),1st,25,female,0,4']

# %% [markdown]
# Create DataFrame from RDD

# %%
#Parse and Load the data into a dataframe. The code calls the parsing function defined above
documents = data.filter(lambda s: "Name" not in s).map(parseDocument)
TitanicData = documents.toDF() # ToDataFrame
print ("Number of records: " + str(TitanicData.count()))
print ( "First 5 records: ")
TitanicData.take(5)
# Out:
# Number of records: 756
# First 5 records:
# [Row(PersonID='1', PersonInfo='1st 29 female', label=1.0),
#  Row(PersonID='2', PersonInfo='1st 2 female', label=0.0),
#  Row(PersonID='3', PersonInfo='1st 30 male', label=0.0),
#  Row(PersonID='4', PersonInfo='1st 25 female', label=0.0),
#  Row(PersonID='5', PersonInfo='1st 0.92 male', label=1.0)]

# %% [markdown]
# <a id="training_test"></a>
# ## Split Data into Training and Test set
#
# We divide the data into training and test set.  The training set is used to build the model to be used on future data, and the test set is used to evaluate the model.

# %%
# Divide the data into training and test set
(train, test) = TitanicData.randomSplit([0.8, 0.2])
print ("Number of records in the training set: " + str(train.count()))
print ("Number of records in the test set: " + str(test.count()))
# Output first 20 records in the training set
print ("First 20 records in the training set: ")
train.show()
# Out:
# Number of records in the training set: 616
# Number of records in the test set: 140
# First 20 records in the training set:
# +--------+-------------+-----+
# |PersonID|   PersonInfo|label|
# +--------+-------------+-----+
# |       1|1st 29 female|  1.0|
# |      10|  1st 71 male|  0.0|
# |     100|  1st 46 male|  0.0|
# |     102|1st 21 female|  1.0|
# |     103|  1st 48 male|  1.0|
# |     105|  1st 45 male|  0.0|
# |     106|1st 36 female|  1.0|
# |     107|  1st 55 male|  0.0|
# |     108|1st 52 female|  1.0|
# |     109|1st 24 female|  1.0|
# |      11|  1st 47 male|  0.0|
# |     110|1st 16 female|  1.0|
# |     111|1st 44 female|  1.0|
# |     112|1st 51 female|  1.0|
# |     113|  1st 42 male|  0.0|
# |     114|1st 35 female|  1.0|
# |     115|  1st 35 male|  1.0|
# |     116|  1st 38 male|  1.0|
# |     117|1st 35 female|  1.0|
# |     119|  1st 49 male|  1.0|
# +--------+-------------+-----+
# only showing top 20 rows

# %% [markdown]
# <a id="build_model"></a>
# ## Build Logistic Regression Model
#
# We use the Pipeline of SparkML to build the Logistic Regression Model

# %%
# set up Logistic Regression using Pipeline of SparkML
tokenizer = Tokenizer(inputCol="PersonInfo", outputCol="words")
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
lr = LogisticRegression(maxIter=10, regParam=0.01)
pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])

# %%
# set up Logistic Regression Model
# the stages are executed in order
model = pipeline.fit(train)
#[stage.coefficients for stage in model.stages if hasattr(stage, "coefficients")]
# model.stages[2].intercept

# %% [markdown]
# <a id="test_data"></a>
# ## Predict for Test data

# %%
# Make predictions for test data and print columns of interest
prediction = model.transform(test)
selected = prediction.select("PersonInfo", "prediction", "probability")
for row in selected.collect():
    print (row)
# Out:
# Row(PersonInfo='1st 25 male', prediction=0.0, probability=DenseVector([0.6485, 0.3515]))
# Row(PersonInfo='1st 49 female', prediction=1.0, probability=DenseVector([0.0417, 0.9583]))
# Row(PersonInfo='1st 50 female', prediction=1.0, probability=DenseVector([0.0862, 0.9138]))
# Row(PersonInfo='1st 42 male', prediction=0.0, probability=DenseVector([0.6647, 0.3353]))
# Row(PersonInfo='1st 29 male', prediction=1.0, probability=DenseVector([0.4598, 0.5402]))
# Row(PersonInfo='1st 30 male', prediction=0.0, probability=DenseVector([0.7076, 0.2924]))
# Row(PersonInfo='1st 15 female', prediction=1.0, probability=DenseVector([0.0197, 0.9803]))
# Row(PersonInfo='1st 33 female', prediction=1.0, probability=DenseVector([0.0299, 0.9701]))
# Row(PersonInfo='1st 44 male', prediction=0.0, probability=DenseVector([0.6104, 0.3896]))
# Row(PersonInfo='1st 37 female', prediction=1.0, probability=DenseVector([0.1657, 0.8343]))
# Row(PersonInfo='1st 47 male', prediction=0.0, probability=DenseVector([0.8278, 0.1722]))
# Row(PersonInfo='1st 64 male', prediction=0.0, probability=DenseVector([0.8774, 0.1226]))
# Row(PersonInfo='1st 22 male', prediction=1.0, probability=DenseVector([0.4824, 0.5176]))
# Row(PersonInfo='1st 17 female', prediction=1.0, probability=DenseVector([0.0579, 0.9421]))
# Row(PersonInfo='1st 52 male', prediction=0.0, probability=DenseVector([0.8064, 0.1936]))
# Row(PersonInfo='1st 55 male', prediction=0.0, probability=DenseVector([0.7469, 0.2531]))
# Row(PersonInfo='1st 21 female', prediction=1.0, probability=DenseVector([0.0704, 0.9296]))
# Row(PersonInfo='1st 50 male', prediction=0.0, probability=DenseVector([0.6086, 0.3914]))
# Row(PersonInfo='1st 39 female', prediction=1.0, probability=DenseVector([0.0957, 0.9043]))
# Row(PersonInfo='1st 56 male', prediction=1.0, probability=DenseVector([0.4762, 0.5238]))
# Row(PersonInfo='1st 24 male', prediction=0.0, probability=DenseVector([0.5411, 0.4589]))
# Row(PersonInfo='1st 23 female', prediction=1.0, probability=DenseVector([0.0813, 0.9187]))
# Row(PersonInfo='1st 62 male', prediction=1.0, probability=DenseVector([0.1868, 0.8132]))
# Row(PersonInfo='1st 52 female', prediction=1.0, probability=DenseVector([0.2018, 0.7982]))
# Row(PersonInfo='1st 61 male', prediction=0.0, probability=DenseVector([0.9674, 0.0326]))
# Row(PersonInfo='1st 39 female', prediction=1.0, probability=DenseVector([0.0957, 0.9043]))
# Row(PersonInfo='1st 57 male', prediction=0.0, probability=DenseVector([0.9762, 0.0238]))
# Row(PersonInfo='1st 32 male', prediction=1.0, probability=DenseVector([0.1571, 0.8429]))
# Row(PersonInfo='1st 33 male', prediction=1.0, probability=DenseVector([0.3369, 0.6631]))
# Row(PersonInfo='2nd 32 female', prediction=1.0, probability=DenseVector([0.0505, 0.9495]))
# Row(PersonInfo='2nd 18 male', prediction=0.0, probability=DenseVector([0.896, 0.104]))
# Row(PersonInfo='2nd 19 female', prediction=1.0, probability=DenseVector([0.0953, 0.9047]))
# Row(PersonInfo='2nd 4 female', prediction=1.0, probability=DenseVector([0.0595, 0.9405]))
# Row(PersonInfo='2nd 12 female', prediction=1.0, probability=DenseVector([0.2374, 0.7626]))
# Row(PersonInfo='2nd 42 female', prediction=1.0, probability=DenseVector([0.3614, 0.6386]))
# Row(PersonInfo='2nd 26 male', prediction=0.0, probability=DenseVector([0.7641, 0.2359]))
# Row(PersonInfo='2nd 0.83 male', prediction=1.0, probability=DenseVector([0.0244, 0.9756]))
# Row(PersonInfo='2nd 52 male', prediction=0.0, probability=DenseVector([0.9514, 0.0486]))
# Row(PersonInfo='1st 45 female', prediction=1.0, probability=DenseVector([0.0515, 0.9485]))
# Row(PersonInfo='2nd 27 male', prediction=0.0, probability=DenseVector([0.8039, 0.1961]))
# Row(PersonInfo='2nd 16 male', prediction=0.0, probability=DenseVector([0.8103, 0.1897]))
# Row(PersonInfo='2nd 26 male', prediction=0.0, probability=DenseVector([0.7641, 0.2359]))
# Row(PersonInfo='2nd 44 male', prediction=0.0, probability=DenseVector([0.8805, 0.1195]))
# Row(PersonInfo='2nd 7 female', prediction=1.0, probability=DenseVector([0.2374, 0.7626]))
# Row(PersonInfo='2nd 24 female', prediction=1.0, probability=DenseVector([0.2518, 0.7482]))
# Row(PersonInfo='1st 60 female', prediction=1.0, probability=DenseVector([0.0523, 0.9477]))
# Row(PersonInfo='2nd 33 male', prediction=0.0, probability=DenseVector([0.705, 0.295]))
# Row(PersonInfo='2nd 23 female', prediction=1.0, probability=DenseVector([0.2938, 0.7062]))
# Row(PersonInfo='2nd 26 female', prediction=1.0, probability=DenseVector([0.1643, 0.8357]))
# Row(PersonInfo='2nd 1 female', prediction=1.0, probability=DenseVector([0.0028, 0.9972]))
# Row(PersonInfo='2nd 27 male', prediction=0.0, probability=DenseVector([0.8039, 0.1961]))
# Row(PersonInfo='1st 33 male', prediction=1.0, probability=DenseVector([0.3369, 0.6631]))
# Row(PersonInfo='1st 36 male', prediction=1.0, probability=DenseVector([0.468, 0.532]))
# Row(PersonInfo='1st 36 female', prediction=1.0, probability=DenseVector([0.0507, 0.9493]))
# Row(PersonInfo='1st 38 female', prediction=1.0, probability=DenseVector([0.1386, 0.8614]))
# Row(PersonInfo='1st 47 male', prediction=0.0, probability=DenseVector([0.8278, 0.1722]))
# Row(PersonInfo='1st 27 female', prediction=1.0, probability=DenseVector([0.0502, 0.9498]))
# Row(PersonInfo='1st 27 female', prediction=1.0, probability=DenseVector([0.0502, 0.9498]))
# Row(PersonInfo='1st 36 female', prediction=1.0, probability=DenseVector([0.0507, 0.9493]))
# Row(PersonInfo='1st 23 female', prediction=1.0, probability=DenseVector([0.0813, 0.9187]))
# Row(PersonInfo='1st 60 female', prediction=1.0, probability=DenseVector([0.0523, 0.9477]))
# Row(PersonInfo='1st 49 male', prediction=1.0, probability=DenseVector([0.4174, 0.5826]))
# Row(PersonInfo='1st 22 female', prediction=1.0, probability=DenseVector([0.0535, 0.9465]))
# Row(PersonInfo='1st 22 female', prediction=1.0, probability=DenseVector([0.0535, 0.9465]))
# Row(PersonInfo='1st 45 female', prediction=1.0, probability=DenseVector([0.0515, 0.9485]))
# Row(PersonInfo='1st 45 female', prediction=1.0, probability=DenseVector([0.0515, 0.9485]))
# Row(PersonInfo='1st 23 male', prediction=0.0, probability=DenseVector([0.593, 0.407]))
# Row(PersonInfo='2nd 19 male', prediction=0.0, probability=DenseVector([0.6343, 0.3657]))
# Row(PersonInfo='2nd 19 male', prediction=0.0, probability=DenseVector([0.6343, 0.3657]))
# Row(PersonInfo='2nd 50 female', prediction=1.0, probability=DenseVector([0.3074, 0.6926]))
# Row(PersonInfo='2nd 42 female', prediction=1.0, probability=DenseVector([0.3614, 0.6386]))
# Row(PersonInfo='2nd 21 male', prediction=0.0, probability=DenseVector([0.8544, 0.1456]))
# Row(PersonInfo='2nd 2 female', prediction=1.0, probability=DenseVector([0.1756, 0.8244]))
# Row(PersonInfo='2nd 30 female', prediction=1.0, probability=DenseVector([0.4085, 0.5915]))
# Row(PersonInfo='2nd 25 female', prediction=1.0, probability=DenseVector([0.345, 0.655]))
# Row(PersonInfo='2nd 30 female', prediction=1.0, probability=DenseVector([0.4085, 0.5915]))
# Row(PersonInfo='2nd 30 female', prediction=1.0, probability=DenseVector([0.4085, 0.5915]))
# Row(PersonInfo='2nd 41 male', prediction=0.0, probability=DenseVector([0.8425, 0.1575]))
# Row(PersonInfo='2nd 23 male', prediction=0.0, probability=DenseVector([0.8726, 0.1274]))
# Row(PersonInfo='2nd 12 female', prediction=1.0, probability=DenseVector([0.2374, 0.7626]))
# Row(PersonInfo='2nd 36 female', prediction=1.0, probability=DenseVector([0.2007, 0.7993]))
# Row(PersonInfo='2nd 28 male', prediction=0.0, probability=DenseVector([0.8835, 0.1165]))
# Row(PersonInfo='3rd 16 female', prediction=1.0, probability=DenseVector([0.3665, 0.6335]))
# Row(PersonInfo='3rd 40 female', prediction=1.0, probability=DenseVector([0.4658, 0.5342]))
# Row(PersonInfo='3rd 18 female', prediction=0.0, probability=DenseVector([0.5385, 0.4615]))
# Row(PersonInfo='3rd 35 male', prediction=0.0, probability=DenseVector([0.8982, 0.1018]))
# Row(PersonInfo='3rd 32 male', prediction=0.0, probability=DenseVector([0.6617, 0.3383]))
# Row(PersonInfo='3rd 11 female', prediction=1.0, probability=DenseVector([0.1735, 0.8265]))
# Row(PersonInfo='3rd 23 male', prediction=0.0, probability=DenseVector([0.9386, 0.0614]))
# Row(PersonInfo='3rd 26 male', prediction=0.0, probability=DenseVector([0.8784, 0.1216]))
# Row(PersonInfo='3rd 15 female', prediction=1.0, probability=DenseVector([0.1738, 0.8262]))
# Row(PersonInfo='3rd 18 female', prediction=0.0, probability=DenseVector([0.5385, 0.4615]))
# Row(PersonInfo='3rd 27 female', prediction=1.0, probability=DenseVector([0.3569, 0.6431]))
# Row(PersonInfo='3rd 19 male', prediction=0.0, probability=DenseVector([0.7946, 0.2054]))
# Row(PersonInfo='3rd 26 male', prediction=0.0, probability=DenseVector([0.8784, 0.1216]))
# Row(PersonInfo='3rd 32 male', prediction=0.0, probability=DenseVector([0.6617, 0.3383]))
# Row(PersonInfo='3rd 40 male', prediction=0.0, probability=DenseVector([0.9349, 0.0651]))
# Row(PersonInfo='3rd 32 female', prediction=1.0, probability=DenseVector([0.1061, 0.8939]))
# Row(PersonInfo='3rd 20 female', prediction=1.0, probability=DenseVector([0.3446, 0.6554]))
# Row(PersonInfo='3rd 19 male', prediction=0.0, probability=DenseVector([0.7946, 0.2054]))
# Row(PersonInfo='3rd 33 male', prediction=0.0, probability=DenseVector([0.842, 0.158]))
# Row(PersonInfo='3rd 20 male', prediction=0.0, probability=DenseVector([0.8965, 0.1035]))
# Row(PersonInfo='3rd 31 male', prediction=0.0, probability=DenseVector([0.925, 0.075]))
# Row(PersonInfo='3rd 30 female', prediction=0.0, probability=DenseVector([0.6064, 0.3936]))
# Row(PersonInfo='3rd 36 female', prediction=1.0, probability=DenseVector([0.359, 0.641]))
# Row(PersonInfo='3rd 19 male', prediction=0.0, probability=DenseVector([0.7946, 0.2054]))
# Row(PersonInfo='3rd 22 female', prediction=1.0, probability=DenseVector([0.3724, 0.6276]))
# Row(PersonInfo='3rd 0.33 male', prediction=0.0, probability=DenseVector([0.9196, 0.0804]))
# Row(PersonInfo='3rd 33 female', prediction=1.0, probability=DenseVector([0.2444, 0.7556]))
# Row(PersonInfo='3rd 25 male', prediction=0.0, probability=DenseVector([0.9509, 0.0491]))
# Row(PersonInfo='3rd 36 female', prediction=1.0, probability=DenseVector([0.359, 0.641]))
# Row(PersonInfo='3rd 23 male', prediction=0.0, probability=DenseVector([0.9386, 0.0614]))
# Row(PersonInfo='3rd 43 male', prediction=0.0, probability=DenseVector([0.9409, 0.0591]))
# Row(PersonInfo='3rd 32 male', prediction=0.0, probability=DenseVector([0.6617, 0.3383]))
# Row(PersonInfo='3rd 24 male', prediction=0.0, probability=DenseVector([0.9252, 0.0748]))
# Row(PersonInfo='3rd 16 male', prediction=0.0, probability=DenseVector([0.905, 0.095]))
# Row(PersonInfo='3rd 48 female', prediction=1.0, probability=DenseVector([0.3003, 0.6997]))
# Row(PersonInfo='3rd 25 male', prediction=0.0, probability=DenseVector([0.9509, 0.0491]))
# Row(PersonInfo='3rd 38 female', prediction=0.0, probability=DenseVector([0.6279, 0.3721]))
# Row(PersonInfo='3rd 43 female', prediction=1.0, probability=DenseVector([0.4912, 0.5088]))
# Row(PersonInfo='3rd 10 female', prediction=0.0, probability=DenseVector([0.9636, 0.0364]))
# Row(PersonInfo='3rd 41 male', prediction=0.0, probability=DenseVector([0.9227, 0.0773]))
# Row(PersonInfo='3rd 43 male', prediction=0.0, probability=DenseVector([0.9409, 0.0591]))
# Row(PersonInfo='3rd 48 male', prediction=0.0, probability=DenseVector([0.8761, 0.1239]))
# Row(PersonInfo='3rd 17 male', prediction=0.0, probability=DenseVector([0.914, 0.086]))
# Row(PersonInfo='3rd 49 male', prediction=0.0, probability=DenseVector([0.8825, 0.1175]))
# Row(PersonInfo='3rd 33 male', prediction=0.0, probability=DenseVector([0.842, 0.158]))
# Row(PersonInfo='3rd 4 male', prediction=0.0, probability=DenseVector([0.6991, 0.3009]))
# Row(PersonInfo='3rd 19 male', prediction=0.0, probability=DenseVector([0.7946, 0.2054]))
# Row(PersonInfo='3rd 27 male', prediction=0.0, probability=DenseVector([0.9014, 0.0986]))
# Row(PersonInfo='3rd 22 male', prediction=0.0, probability=DenseVector([0.9072, 0.0928]))
# Row(PersonInfo='3rd 21 female', prediction=1.0, probability=DenseVector([0.4427, 0.5573]))
# Row(PersonInfo='3rd 4 female', prediction=1.0, probability=DenseVector([0.1236, 0.8764]))
# Row(PersonInfo='3rd 25 male', prediction=0.0, probability=DenseVector([0.9509, 0.0491]))
# Row(PersonInfo='3rd 37 female', prediction=0.0, probability=DenseVector([0.6756, 0.3244]))
# Row(PersonInfo='3rd 21 female', prediction=1.0, probability=DenseVector([0.4427, 0.5573]))
# Row(PersonInfo='3rd 45 female', prediction=1.0, probability=DenseVector([0.363, 0.637]))
# Row(PersonInfo='3rd 63 female', prediction=0.0, probability=DenseVector([0.9043, 0.0957]))
# Row(PersonInfo='3rd 28 male', prediction=0.0, probability=DenseVector([0.9442, 0.0558]))
# Row(PersonInfo='3rd 30 female', prediction=0.0, probability=DenseVector([0.6064, 0.3936]))

# %%
#Tabulate the predicted outcome
prediction.select("prediction").groupBy("prediction").count().show(truncate=False)
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |0.0       |70   |
# |1.0       |70   |
# +----------+-----+

# %%
#Tabulate the actual outcome
prediction.select("label").groupBy("label").count().show(truncate=False)
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |0.0  |77   |
# |1.0  |63   |
# +-----+-----+

# %%
# This table shows:
# 1. The number of passengers who survived predicted as died
# 2. The number of passengers who survived predicted as survived
# 3. The number of passengers who died predicted as died
# 4. The number of passengers who died predicted as survived

prediction.crosstab('label', 'prediction').show()
# Out:
# +----------------+---+---+
# |label_prediction|0.0|1.0|
# +----------------+---+---+
# |             1.0| 13| 50|
# |             0.0| 57| 20|
# +----------------+---+---+

# %% [markdown]
# <a id="evaluate_model"></a>
# ## Evaluate the Model
#
# We evaluate the model on a training set and on a test set.  The purpose is to measure the model's predictive accuracy, including the accuracy for new data.

# %%
# Evaluate the Logistic Regression model on a training set
# Select (prediction, true label) and compute test error
pred_lr=model.transform(train).select("prediction", "label")
eval_lr=MulticlassClassificationEvaluator (
    labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy_lr=eval_lr.evaluate(pred_lr)
# create RDD
predictionAndLabels_lr=pred_lr.rdd
metrics_lr=MulticlassMetrics(predictionAndLabels_lr)
precision_lr=metrics_lr.precision(1.0)
recall_lr=metrics_lr.recall(1.0)
f1Measure_lr = metrics_lr.fMeasure(1.0, 1.0)
print ("Model evaluation for the training data")
print ("Accuracy = %s" %accuracy_lr)
print ("Error = %s" % (1-accuracy_lr))
print ("Precision = %s" %precision_lr)
print ("Recall = %s" %recall_lr)
print("F1 Measure = %s" % f1Measure_lr)
# Out:
# /opt/ibm/spark/python/lib/pyspark.zip/pyspark/sql/context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
# Model evaluation for the training data
# Accuracy = 0.823051948051948
# Error = 0.17694805194805197
# Precision = 0.7854251012145749
# Recall = 0.776
# F1 Measure = 0.7806841046277667

# %%
# Evaluate the Logistic Regression model on a test set
# Select (prediction, true label) and compute test error
pred_lr=model.transform(test).select("prediction", "label")
eval_lr=MulticlassClassificationEvaluator (
    labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy_lr=eval_lr.evaluate(pred_lr)
# create RDD
predictionAndLabels_lr=pred_lr.rdd
metrics_lr=MulticlassMetrics(predictionAndLabels_lr)
precision_lr=metrics_lr.precision(1.0)
recall_lr=metrics_lr.recall(1.0)
f1Measure_lr = metrics_lr.fMeasure(1.0, 1.0)
print ("Model evaluation for the test data")
print ("Accuracy = %s" %accuracy_lr)
print ("Error = %s" % (1-accuracy_lr))
print ("Precision = %s" %precision_lr)
print ("Recall = %s" %recall_lr)
print ("F1 Measure = %s" % f1Measure_lr)
# Out:
# Model evaluation for the test data
# Accuracy = 0.7642857142857142
# Error = 0.23571428571428577
# Precision = 0.7142857142857143
# Recall = 0.7936507936507936
# F1 Measure = 0.7518796992481204

# %%
bin_lr=BinaryClassificationMetrics(predictionAndLabels_lr)

# Area under precision-recall curve
print("Area under PR = %s" % bin_lr.areaUnderPR)
# Area under Receiver operating characteristic curve
print("Area under ROC = %s" % bin_lr.areaUnderROC)
# Out:
# Area under PR = 0.6870181405895692
# Area under ROC = 0.766955266955267

# %% [markdown]
# <a id="ROC_plot"></a>
# ## ROC Curve Plot
# The Binary Logistic Regression method returns the pyspark.ml.classification.BinaryLogisticRegressionTrainingSummary object. We may use the roc method to obtain the coordinates of the points on Receiver operating characteristic (ROC) curve.  The coordinates are stored in a Dataframe with two fields FPR=false positive rate and TPR=true positive rate

# %%
#The firt 20 ROC curve points
model.stages[2].summary.roc.show()
# Out:
# +-------------------+-----+
# |                FPR|  TPR|
# +-------------------+-----+
# |                0.0|  0.0|
# |                0.0|0.004|
# |                0.0|0.012|
# |                0.0|0.016|
# |                0.0| 0.02|
# |                0.0|0.028|
# |                0.0|0.036|
# |                0.0|0.052|
# |                0.0|0.056|
# |                0.0| 0.06|
# |                0.0|0.064|
# |                0.0| 0.08|
# |                0.0|0.084|
# |                0.0|0.088|
# |0.00273224043715847|0.088|
# |0.00273224043715847|0.096|
# |0.00273224043715847|0.104|
# |0.00273224043715847|0.108|
# |0.00273224043715847|0.112|
# |0.00273224043715847|0.124|
# +-------------------+-----+
# only showing top 20 rows

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ROC=model.stages[2].summary.roc
df=ROC.toPandas()

df.plot(x='FPR', y='TPR', legend=False)
# Out:
# <Axes: xlabel='FPR'>
